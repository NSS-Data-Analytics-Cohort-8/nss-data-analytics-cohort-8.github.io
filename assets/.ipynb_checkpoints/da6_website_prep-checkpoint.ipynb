# %%
import pandas as pd
import json

# %%
website = pd.read_csv('da6_website_info - Sheet1.csv')

# %%
website.head()
# Out:
#      First    Last                                           LinkedIn  \
# 0      Abi  Inglis        https://www.linkedin.com/in/abigailtinglis/
# 1  Abigail   Asper          https://www.linkedin.com/in/abigailasper/
# 2   Andrew   Scott  https://www.linkedin.com/in/andrew-barnett-scott/
# 3   Aurora  Larson         https://www.linkedin.com/in/aurora-larson/
# 4  Caitlyn   Brown         https://www.linkedin.com/in/caitlynabrown/
#
#                              Github Resume  \
# 0    https://github.com/atinglis314      x
# 1   https://github.com/abigailasper      x
# 2      https://github.com/ABscott94      x
# 3  https://github.com/AuroraDelaney      x
# 4    https://github.com/caitbrown12      x
#
#                                      Capstone (link)  \
# 0  https://github.com/atinglis314/NSS-DA6-Abi-Cap...
# 1       https://github.com/abigailasper/nss-capstone
# 2                                                NaN
# 3    https://github.com/AuroraDelaney/hello_capstone
# 4        https://github.com/caitbrown12/NSS_Capstone
#
#                                              Tagline  \
# 0  "Make just a ripple. Come on, be brave. This t...
# 1  "You'll never do a whole lot unless you're bra...
# 2  "When someone thoroughly exhausts an experienc...
# 3  "Somewhere, something incredible is waiting to...
# 4  "Start where you are. Use what you have. Do wh...
#
#                                                  Bio   pro_img   fun_img  \
# 0  I am an excellent communicator and emerging da...      Abi1      Abi2
# 1  I have always valued evidence-based, data-driv...  abigail1  abigail2
# 2  Clear communicator with an adept sense of orga...       NaN       NaN
# 3  I’m a natural storyteller and the thing that m...   Aurora1       NaN
# 4  For the last three years, I have worked as a S...  Caitlyn1  Caitlyn2
#
#    podcast                         Email  Capstone (video)
# 0      NaN    abigail.t.inglis@gmail.com               NaN
# 1      NaN        abigailasper@gmail.com               NaN
# 2      NaN  andrewbarnettscott@gmail.com               NaN
# 3      NaN          roryvick93@gmail.com               NaN
# 4      NaN     caitlyn.a.brown@gmail.com               NaN

# %%
website.columns
# Out:
# Index(['First', 'Last', 'LinkedIn', 'Github', 'Resume', 'Capstone (link)',
#        'Tagline', 'Bio', 'pro_img', 'fun_img', 'podcast', 'Email',
#        'Capstone (video)'],
#       dtype='object')

# %%
website = website.rename(columns = {
    'First': 'firstName',
    'Last': 'lastName',
    'Tagline': 'reelThemIn',
    'Bio': 'bio',
    'Github': 'github',
    'LinkedIn': 'linkedIn',
    'Capstone (link)': 'portfolio',
    'Email': 'email'
})

# %%
website
# Out:
#    firstName    lastName                                           linkedIn  \
# 0        Abi      Inglis        https://www.linkedin.com/in/abigailtinglis/
# 1    Abigail       Asper          https://www.linkedin.com/in/abigailasper/
# 2     Andrew       Scott  https://www.linkedin.com/in/andrew-barnett-scott/
# 3     Aurora      Larson         https://www.linkedin.com/in/aurora-larson/
# 4    Caitlyn       Brown         https://www.linkedin.com/in/caitlynabrown/
# 5    Heather     Botting       https://www.linkedin.com/in/heather-botting/
# 6      Iulia       Goike            https://www.linkedin.com/in/iuliagoike/
# 7    Jasmine   Drumright           https://www.linkedin.com/in/jmdrumright/
# 8      Jason    Thompson  https://www.linkedin.com/in/jason-thompson-dat...
# 9       Kate     Hartley                                                NaN
# 10    Katie      Garrett         https://www.linkedin.com/in/katie-garrett/
# 11     Lance      Roller              www.linkedin.com/in/lance-roller-ii\r
# 12    Maggie     DeCampo               https://www.linkedin.com/in/mdecampo
# 13     Megan        Grim            https://www.linkedin.com/in/megan-grim/
# 14    Nathan      Martin        www.linkedin.com/in/nathan-martin-186615237
# 15   Patrick  Cunningham  http://www.linkedin.com/in/patrickcunningham-c...
# 16      Phil      George           https://www.linkedin.com/in/philwgeorge/
# 17       Rob   Schulteis          https://www.linkedin.com/in/robschulteis/
# 18      Rudy        Moya              https://www.linkedin.com/in/rudy-moya
# 19     Scott    Schriver         https://www.linkedin.com/in/scottschriver/
#
#                                  github Resume  \
# 0        https://github.com/atinglis314      x
# 1       https://github.com/abigailasper      x
# 2          https://github.com/ABscott94      x
# 3      https://github.com/AuroraDelaney      x
# 4        https://github.com/caitbrown12      x
# 5        https://github.com/heatherkayb      x
# 6             https://github.com/igoike      x
# 7        https://github.com/jmdrumright      x
# 8       https://github.com/jrthompson25      x
# 9                                   NaN    NaN
# 10        https://github.com/kmgarrett1      x
# 11      https://github.com/LJRollerII\r      x
# 12          https://github.com/mdecampo      x
# 13         https://github.com/Megan1034      x
# 14  https://github.com/nathanmartin5937      x
# 15          https://github.com/Cuiweiyi      X
# 16     https://github.com/worldsbestdad      x
# 17      https://github.com/robschulteis      x
# 18         https://github.com/mrmoya413      x
# 19             github.com/scottschriver      x
#
#                                             portfolio  \
# 0   https://github.com/atinglis314/NSS-DA6-Abi-Cap...
# 1        https://github.com/abigailasper/nss-capstone
# 2                                                 NaN
# 3     https://github.com/AuroraDelaney/hello_capstone
# 4         https://github.com/caitbrown12/NSS_Capstone
# 5   https://github.com/heatherkayb/heatherkayb_cap...
# 6                  https://github.com/igoike/Capstone
# 7      https://github.com/jmdrumright/AgAidFromAbroad
# 8   https://github.com/jrthompson25/Capstone-Resta...
# 9                                                 NaN
# 10  https://github.com/kmgarrett1/Capstone_Project...
# 11  https://github.com/LJRollerII/NSS_Capstone_Pro...
# 12   https://github.com/mdecampo/Maggies_NSS_Capstone
# 13        https://github.com/Megan1034/turbo-lamp.git
# 14   https://github.com/nathanmartin5937/capstone.git
# 15        https://github.com/Cuiweiyi/CALEA_and_crime
# 16  https://github.com/worldsbestdad/capstone-cass...
# 17      https://github.com/robschulteis/noaa-capstone
# 18     https://github.com/mrmoya413/Capstone_RudyMoya
# 19      https://github.com/scottschriver/NSS_Capstone
#
#                                            reelThemIn  \
# 0   "Make just a ripple. Come on, be brave. This t...
# 1   "You'll never do a whole lot unless you're bra...
# 2   "When someone thoroughly exhausts an experienc...
# 3   "Somewhere, something incredible is waiting to...
# 4   "Start where you are. Use what you have. Do wh...
# 5              "It doesn't have to be fun to be fun."
# 6   “We cannot solve problems with the kind of thi...
# 7       "Have you tried turning it off and on again?"
# 8   "Success is achieved through a committment to ...
# 9                                                 NaN
# 10  "“The world is one big data problem.”- Andrew ...
# 11                "Without honor, victory is hollow."
# 12  "The harder you work for something, the better...
# 13  "Good lumber doesn't come with ease; the stron...
# 14  "Inspiration does exist, but it must find you ...
# 15  “It does not matter how slowly you go, as long...
# 16  "We are stuck with technology when what we rea...
# 17  "Chasing a dream is a never-ending negotiation...
# 18  "You miss 100% of the shots you don't take. - ...
# 19  "It's a funny thing about life; if you refuse ...
#
#                                                   bio   pro_img   fun_img  \
# 0   I am an excellent communicator and emerging da...      Abi1      Abi2
# 1   I have always valued evidence-based, data-driv...  abigail1  abigail2
# 2   Clear communicator with an adept sense of orga...       NaN       NaN
# 3   I’m a natural storyteller and the thing that m...   Aurora1       NaN
# 4   For the last three years, I have worked as a S...  Caitlyn1  Caitlyn2
# 5   I double majored in English and economics beca...  heather1  heather2
# 6    For the past 5 years I've been working as a d...    Iulia1    Iulia2
# 7   For two years I worked in museums for my homet...  jasmine1  jasmine2
# 8   Logical Data Analyst with a passion for extrac...    jason1       NaN
# 9                                                 NaN       NaN       NaN
# 10  I am currently a librarian looking to transiti...    Katie1    Katie2
# 11  I'm an enthusiastic, detail oriented, and inte...    Lance1       NaN
# 12  My interest and skills in data-based decision ...   Maggie1   Maggie2
# 13  Results-focused, professional with strength in...    Megan1    Megan2
# 14  I'm Nathan Martin and I'm a passionate analyst...   Nathan1       NaN
# 15  Taught English abroad in mainland China for 2 ...  Patrick1  Patrick2
# 16  I enjoyed analyzing data in my engineering pos...     Phil1     Phil2
# 17  When it comes to trouble-shooting and managing...      Rob1      Rob2
# 18  I'm Rudy Moya, a Data Analyst that's enthusias...     Rudy1     Rudy2
# 19  Engineer and Data Analyst. I've worked in both...    Scott1  deleted?
#
#     podcast                         email  Capstone (video)
# 0       NaN    abigail.t.inglis@gmail.com               NaN
# 1       NaN        abigailasper@gmail.com               NaN
# 2       NaN  andrewbarnettscott@gmail.com               NaN
# 3       NaN          roryvick93@gmail.com               NaN
# 4       NaN     caitlyn.a.brown@gmail.com               NaN
# 5       NaN         heatherkaym@gmail.com               NaN
# 6       NaN         iuliaisaeva@gmail.com               NaN
# 7       NaN         jmdrumright@gmail.com               NaN
# 8       NaN      jrthompson35@outlook.com               NaN
# 9       NaN                           NaN               NaN
# 10      NaN        katiegarrett@gmail.com               NaN
# 11      NaN                           NaN               NaN
# 12      NaN            mdecampo@gmail.com               NaN
# 13      NaN         megan.grim4@gmail.com               NaN
# 14      NaN    nathanmartin5937@gmail.com               NaN
# 15      NaN     pcunningham1489@yahoo.com               NaN
# 16      NaN       philipwgeorge@gmail.com               NaN
# 17      NaN        robschulteis@gmail.com               NaN
# 18      NaN           mr.moya83@gmail.com               NaN
# 19      NaN    scott.schriver@comcast.net               NaN

# %%
for col in ['firstName', 'lastName']:
    website[col] = website[col].str.strip()

# %% [markdown]
# Create an empty dictionary.

# %%
cohort = {"cohort": []}

# %%
website = website.reset_index()

# %%
website = website.rename(columns = {'index': 'id'})

# %%
website['proImg'] = 'assets/img/' + website['firstName'].str.lower() + '1.jpg'
website['funImg'] = 'assets/img/' + website['firstName'].str.lower() + '2.jpg'

# %% [markdown]
# For the people missing photos, use the placeholder image.

# %%
missing_photo_folks = ['Scott', 'Hartley']
website.loc[website.lastName.isin(missing_photo_folks), 'proImg'] = 'assets/img/placeholder.jpg'
website.loc[website.lastName.isin(missing_photo_folks), 'funImg'] = 'assets/img/placeholder.jpg'

# %%
website.tail(7)
# Out:
#     id firstName    lastName  \
# 13  13     Megan        Grim
# 14  14    Nathan      Martin
# 15  15   Patrick  Cunningham
# 16  16      Phil      George
# 17  17       Rob   Schulteis
# 18  18      Rudy        Moya
# 19  19     Scott    Schriver
#
#                                              linkedIn  \
# 13            https://www.linkedin.com/in/megan-grim/
# 14        www.linkedin.com/in/nathan-martin-186615237
# 15  http://www.linkedin.com/in/patrickcunningham-c...
# 16           https://www.linkedin.com/in/philwgeorge/
# 17          https://www.linkedin.com/in/robschulteis/
# 18              https://www.linkedin.com/in/rudy-moya
# 19         https://www.linkedin.com/in/scottschriver/
#
#                                  github Resume  \
# 13         https://github.com/Megan1034      x
# 14  https://github.com/nathanmartin5937      x
# 15          https://github.com/Cuiweiyi      X
# 16     https://github.com/worldsbestdad      x
# 17      https://github.com/robschulteis      x
# 18         https://github.com/mrmoya413      x
# 19             github.com/scottschriver      x
#
#                                             portfolio  \
# 13        https://github.com/Megan1034/turbo-lamp.git
# 14   https://github.com/nathanmartin5937/capstone.git
# 15        https://github.com/Cuiweiyi/CALEA_and_crime
# 16  https://github.com/worldsbestdad/capstone-cass...
# 17      https://github.com/robschulteis/noaa-capstone
# 18     https://github.com/mrmoya413/Capstone_RudyMoya
# 19      https://github.com/scottschriver/NSS_Capstone
#
#                                            reelThemIn  \
# 13  "Good lumber doesn't come with ease; the stron...
# 14  "Inspiration does exist, but it must find you ...
# 15  “It does not matter how slowly you go, as long...
# 16  "We are stuck with technology when what we rea...
# 17  "Chasing a dream is a never-ending negotiation...
# 18  "You miss 100% of the shots you don't take. - ...
# 19  "It's a funny thing about life; if you refuse ...
#
#                                                   bio   pro_img   fun_img  \
# 13  Results-focused, professional with strength in...    Megan1    Megan2
# 14  I'm Nathan Martin and I'm a passionate analyst...   Nathan1       NaN
# 15  Taught English abroad in mainland China for 2 ...  Patrick1  Patrick2
# 16  I enjoyed analyzing data in my engineering pos...     Phil1     Phil2
# 17  When it comes to trouble-shooting and managing...      Rob1      Rob2
# 18  I'm Rudy Moya, a Data Analyst that's enthusias...     Rudy1     Rudy2
# 19  Engineer and Data Analyst. I've worked in both...    Scott1  deleted?
#
#     podcast                       email  Capstone (video)  \
# 13      NaN       megan.grim4@gmail.com               NaN
# 14      NaN  nathanmartin5937@gmail.com               NaN
# 15      NaN   pcunningham1489@yahoo.com               NaN
# 16      NaN     philipwgeorge@gmail.com               NaN
# 17      NaN      robschulteis@gmail.com               NaN
# 18      NaN         mr.moya83@gmail.com               NaN
# 19      NaN  scott.schriver@comcast.net               NaN
#
#                      proImg                   funImg
# 13    assets/img/megan1.jpg    assets/img/megan2.jpg
# 14   assets/img/nathan1.jpg   assets/img/nathan2.jpg
# 15  assets/img/patrick1.jpg  assets/img/patrick2.jpg
# 16     assets/img/phil1.jpg     assets/img/phil2.jpg
# 17      assets/img/rob1.jpg      assets/img/rob2.jpg
# 18     assets/img/rudy1.jpg     assets/img/rudy2.jpg
# 19    assets/img/scott1.jpg    assets/img/scott2.jpg

# %%
website['resume'] = 'resumes/' + website['firstName'].str.lower().str.replace(' ', '') + '.pdf'

# %%
cohort['cohort'] = json.loads(website[['id', 'firstName', 'lastName', 'linkedIn', 'github', 'email', 'portfolio', 
                                       'reelThemIn', 'bio', 'proImg', 'funImg', 
                                       'resume'
                                      ]].to_json(orient = 'records'))

# %%
with open('cohort.json', 'w') as fi:
    json.dump(cohort, fi)
